# %%
## Importar librerías

import pandas as pd
import warnings
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
## Cargar datos 

data = pd.read_csv('../data/processed/data_eda.csv').sample(frac=0.5)
data.head()
# Out:
#        channel_name  category  Sub-category  Agent_name  Supervisor  Manager  \
# 10881             1        10            40        1038          20        0
# 10671             1        10            40         502          17        0
# 13439             2        10            20        1103           5        5
# 68998             1         5            17        1165          11        3
# 42678             1        10            39        1233          36        2
#
#        Tenure Bucket  Agent Shift  CSAT Score  issue_reported_year  ...  \
# 10881              2            2           5                 2023  ...
# 10671              3            4           4                 2023  ...
# 13439              4            1           5                 2023  ...
# 68998              3            2           5                 2023  ...
# 42678              0            2           5                 2023  ...
#
# ...

# %%
X = data.drop('CSAT Score',axis=1)
y = data['CSAT Score']

# %%
y.isnull().sum()
# Out:
# 0

# %%
## Normalización
scaler = StandardScaler()
df_scaler = scaler.fit_transform(X)
data_scaler_X = pd.DataFrame(df_scaler, columns=X.columns)
data_scaler_X ['CSAT Score']=y.values

# %%
data_scaler_X.to_csv('../data/processed/data_normalized.csv', index=False)
